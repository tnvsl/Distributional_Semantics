# %%
pip install bertopic
# Out:
#   Building wheel for hdbscan (PEP 517) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.29-cp38-cp38-linux_x86_64.whl size=2700856 sha256=fb5cffbf9bb45d9682e70acadf9bed5ddee32fd3337597778d4e82003f6af293
#   Stored in directory: /root/.cache/pip/wheels/76/06/48/527e038689c581cc9e519c73840efdc7473805149e55bd7ffd
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=4c726c9961ea2abf7558df804e6cea860c8f0f00670b27211e1cb9d85b2a8908
#   Stored in directory: /root/.cache/pip/wheels/5e/6f/8c/d88aec621f3f542d26fac0342bef5e693335d125f4e54aeffe
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82829 sha256=aefb92f1e26fd9f0bacb34c36bf13af6dbcc1aabe6de49ed9af4995c4b11311d
#   Stored in directory: /root/.cache/pip/wheels/a9/3a/67/06a8950e053725912e6a8c42c4a3a241410f6487b8402542ea
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55513 sha256=0b52902f561b3d75751b48e7a8b643e436a7d489f880ef9c15e0d8df9238549b
#   Stored in directory: /root/.cache/pip/wheels/1c/63/3a/29954bca1a27ba100ed8c27973a78cb71b43dc67aed62e80c3
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers, sentencepiece, pynndescent, umap-learn, sentence-transformers, hdbscan, bertopic
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
# Successfully installed bertopic-0.12.0 hdbscan-0.8.29 huggingface-hub-0.11.1 pynndescent-0.5.8 pyyaml-5.4.1 sentence-transformers-2.2.2 sentencepiece-0.1.97 tokenizers-0.13.2 transformers-4.25.1 umap-learn-0.5.3

# %%
# coding: utf-8
import codecs
import os
import sklearn
import bertopic

# %%
# !unzip '/content/les_lem.zip'

# %%
PATH = '/content/les_lem'
STW_PATH = '/content/swl_optimum.txt'

# %%
with codecs.open(STW_PATH, encoding = 'utf-8') as f:
#    stw_list = f.read().split()[1:] # тк первый символ - что-то странное: \ufeffа
    stw_list = f.read().split()

# %%
file_names = os.listdir(PATH) 
documents = []
for name in file_names:
    if name.endswith(".txt"):
        with codecs.open(PATH + "/" + name, encoding = 'utf-8') as f:
            data = []
            for word in f.read().split():
                if word not in stw_list:
                    data.append(word)
            document = ' '.join(data)
            documents.append(document)
            # each document should contain lemmatized words separated by spaces

# %%
from sklearn.feature_extraction.text import CountVectorizer 
from bertopic import BERTopic

vectorizer_model = CountVectorizer(stop_words=stw_list, ngram_range=(1,2), min_df=1, max_df=0.95) 
topic_model = BERTopic(language="multilingual", vectorizer_model=vectorizer_model, calculate_probabilities=True, verbose=True)
topics, probs = topic_model.fit_transform(documents)
# Out:
# Downloading:   0%|          | 0.00/968 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/645 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/14.8M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Batches:   0%|          | 0/44 [00:00<?, ?it/s]
# 2022-12-26 17:55:37,505 - BERTopic - Transformed documents to Embeddings
# 2022-12-26 17:55:51,861 - BERTopic - Reduced dimensionality
# 2022-12-26 17:55:52,012 - BERTopic - Clustered reduced embeddings

# %%
freq = topic_model.get_topic_info(); freq.head(40)
# Out:
#     Topic  Count                                               Name
# 0      -1    580                  -1_быть_значение_русский_развитие
# 1       0    171                       0_согласный_фонема_быть_слог
# 2       1    111                     1_быть_развитие_метод_значение
# 3       2    105                    2_значение_речь_быть_глагольный
# 4       3     61                 3_литературный_чел_восточный_падеж
# 5       4     52           4_значение_семантический_единица_признак
# 6       5     43  5_индоевропейский_славянский_литературный_лите...
# 7       6     36           6_романский_письмо_испанский_французский
# 8       7     32                  7_институт_ссср_литовский_русский
# 9       8     28                     8_арабский_письмо_знак_алфавит
# 10      9     26       9_русский_русский язык_словарь_русский языка
# 11     10     23     10_чел_конголезский_нигеро_нигеро конголезский
# 12     11     23                          11_остров_чел_кечуа_южный
# 13     12     21      12_быть_исследование_индоевропейский_японский
# 14     13     19  13_развитие_международный_языкознание_искусств...
# 15     14     17                  14_письмо_буква_алфавит_греческий
# 16     15     16                      15_подгруппа_судан_уганда_луо
# 17     16     12            16_южный_письмо_ацтекский_классификация
# 18     17     11        17_буква_русский_транскрипция_нейтрализация
# 19     18     11         18_реконструкция_праязык_термин_дешифровка

# %%
topic_model.get_topic(0)  # Select the most frequent topic
# Out:
# [('согласный', 0.013026289523461474),
#  ('фонема', 0.008546364932998506),
#  ('быть', 0.007363000527523973),
#  ('слог', 0.0071339011065078735),
#  ('звук', 0.006387441538498118),
#  ('характерный', 0.005763931381197066),
#  ('ударение', 0.005058893514512281),
#  ('звуковой', 0.004835279245310165),
#  ('чередование', 0.0047561242925253005),
#  ('русский', 0.004708919415612151)]

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ab7bc2a0-baf6-478e-89b6-34a4840e74d5" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab7bc2a0-baf6-478e-89b6-34a4840e74d5")) {                    Plotly.newPlot(                        "ab7bc2a0-baf6-478e-89b6-34a4840e74d5",                        [{"customdata":[[0,"\u0441\u043e\u0433\u043b\u0430\u0441\u043d\u044b\u0439 | \u0444\u043e\u043d\u0435\u043c\u0430 | \u0431\u044b\u0442\u044c | \u0441\u043b\u043e\u0433 | \u0437\u0432\u0443\u043a",171],[1,"\u0431\u044b\u0442\u044c | \u0440\u0430\u0437\u0432\u0438\u0442\u0438\u0435 | \u043c\u0435\u0442\u043e\u0434 | \u0437\u043d\u0430\u0447\u0435\u043d\u0438\u0435 | \u0435\u0434\u0438\u043d\u0438\u0446\u0430",111],[2,"\u0437\u043d\u0430\u0447\u0435\u043d\u0438\u0435 | \u0440\u0435\u0447\u044c | \u0431\u044b\u0442\u044c | \u0433\u043b\u0430\u0433\u043e\u043b\u044c\u043d\u044b\u0439 | \u0432\u0438\u0434",105],[3,"\u043b\u0438\u0442\u0435\u0440\u0430\u0442\u0443\u0440\u043d\u044b\u0439 | \u0447\u0435\u043b | \u0432\u043e\u0441\u0442\u043e\u0447\u043d\u044b\u0439 | \u043f\u0430\u0434\u0435\u0436 | \u0442\u044e\u0440\u043a\u0441\u043a\u0438\u0439",61],[4,"\u0437\u043d\u0430\u0447\u0435\u043d\u0438\u0435 | \u0441\u0435\u043c\u0430\u043d\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0439 | \u0435\u0434\u0438\u043d\u0438\u0446\u0430 | \u043f\u0440\u0438\u0437\u043d\u0430\u043a | \u0447\u0438\u0441\u043b\u0438\u0442\u0435\u043b\u044c\u043d\u043e\u0435",52],[5,"\u0438\u043d\u0434\u043e\u0435\u0432\u0440\u043e\u043f\u0435\u0439\u0441\u043a\u0438\u0439 | \u0441\u043b\u0430\u0432\u044f\u043d\u0441\u043a\u0438\u0439 | \u043b\u0438\u0442\u0435\u0440\u0430\u0442\u0443\u0440\u043d\u044b\u0439 | \u043b\u0438\u0442\u0435\u0440\u0430\u0442\u0443\u0440\u043d\u044b\u0439 \u044f\u0437\u044b\u043a | \u043f\u0440\u0430\u0441\u043b\u0430\u0432\u044f\u043d\u0441\u043a\u0438\u0439",43],[6,"\u0440\u043e\u043c\u0430\u043d\u0441\u043a\u0438\u0439 | \u043f\u0438\u0441\u044c\u043c\u043e | \u0438\u0441\u043f\u0430\u043d\u0441\u043a\u0438\u0439 | \u0444\u0440\u0430\u043d\u0446\u0443\u0437\u0441\u043a\u0438\u0439 | \u0440\u043e\u043c\u0430\u043d\u0441\u043a\u0438\u0439 \u044f\u0437\u044b\u043a",36],[7,"\u0438\u043d\u0441\u0442\u0438\u0442\u0443\u0442 | \u0441\u0441\u0441\u0440 | \u043b\u0438\u0442\u043e\u0432\u0441\u043a\u0438\u0439 | \u0440\u0443\u0441\u0441\u043a\u0438\u0439 | \u0441\u043b\u043e\u0432\u0430\u0440\u044c",32],[8,"\u0430\u0440\u0430\u0431\u0441\u043a\u0438\u0439 | \u043f\u0438\u0441\u044c\u043c\u043e | \u0437\u043d\u0430\u043a | \u0430\u043b\u0444\u0430\u0432\u0438\u0442 | \u0437\u0430\u043f\u0430\u0434\u043d\u043e\u0441\u0435\u043c\u0438\u0442\u0441\u043a\u0438\u0439",28],[9,"\u0440\u0443\u0441\u0441\u043a\u0438\u0439 | \u0440\u0443\u0441\u0441\u043a\u0438\u0439 \u044f\u0437\u044b\u043a | \u0441\u043b\u043e\u0432\u0430\u0440\u044c | \u0440\u0443\u0441\u0441\u043a\u0438\u0439 \u044f\u0437\u044b\u043a\u0430 | \u043b\u0438\u0442\u0435\u0440\u0430\u0442\u0443\u0440\u043d\u044b\u0439",26],[10,"\u0447\u0435\u043b | \u043a\u043e\u043d\u0433\u043e\u043b\u0435\u0437\u0441\u043a\u0438\u0439 | \u043d\u0438\u0433\u0435\u0440\u043e | \u043d\u0438\u0433\u0435\u0440\u043e \u043a\u043e\u043d\u0433\u043e\u043b\u0435\u0437\u0441\u043a\u0438\u0439 | \u043f\u043e\u043a\u0430\u0437\u0430\u0442\u0435\u043b\u044c",23],[11,"\u043e\u0441\u0442\u0440\u043e\u0432 | \u0447\u0435\u043b | \u043a\u0435\u0447\u0443\u0430 | \u044e\u0436\u043d\u044b\u0439 | \u0441\u0430\u043f\u0430\u0440\u044b\u0439",23],[12,"\u0431\u044b\u0442\u044c | \u0438\u0441\u0441\u043b\u0435\u0434\u043e\u0432\u0430\u043d\u0438\u0435 | \u0438\u043d\u0434\u043e\u0435\u0432\u0440\u043e\u043f\u0435\u0439\u0441\u043a\u0438\u0439 | \u044f\u043f\u043e\u043d\u0441\u043a\u0438\u043 ...

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1bebfcba-4f74-42dd-a440-e86881d13c10" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1bebfcba-4f74-42dd-a440-e86881d13c10")) {                    Plotly.newPlot(                        "1bebfcba-4f74-42dd-a440-e86881d13c10",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.006387441538498118,0.0071339011065078735,0.007363000527523973,0.008546364932998506,0.013026289523461474],"y":["\u0437\u0432\u0443\u043a  ","\u0441\u043b\u043e\u0433  ","\u0431\u044b\u0442\u044c  ","\u0444\u043e\u043d\u0435\u043c\u0430  ","\u0441\u043e\u0433\u043b\u0430\u0441\u043d\u044b\u0439  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.007640167766083768,0.00813838789972297,0.008327085660688044,0.008503622597451995,0.008644007759430725],"y":["\u0435\u0434\u0438\u043d\u0438\u0446\u0430  ","\u0437\u043d\u0430\u0447\u0435\u043d\u0438\u0435  ","\u043c\u0435\u0442\u043e\u0434  ","\u0440\u0430\u0437\u0432\u0438\u0442\u0438\u0435  ","\u0431\u044b\u0442\u044c  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.006546745360125443,0.006601797899713399,0.008092193942448889,0.009145088456229253,0.009192806100188794],"y":["\u0432\u0438\u0434  ","\u0433\u043b\u0430\u0433\u043e\u043b\u044c\u043d\u044b\u0439  ","\u0431\u044b\u0442\u044c  ","\u0440\u0435\u0447\u044c  ","\u0437\u043d\u0430\u0447\u0435\u043d\u0438\u0435  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.007080746231529713,0.007169249091628806,0.007881278164117728,0.008510632359223622,0.00882598905000737],"y":["\u0442\u044e\u0440\u043a\u0441\u043a\u0438\u0439  ","\u043f\u0430\u0434\u0435\u0436  ","\u0432\u043e\u0441\u0442\u043e\u0447\u043d\u044b\u0439  ","\u0447\u0435\u043b  ","\u043b\u0438\u0442\u0435\u0440\u0430\u0442\u0443\u0440\u043d\u044b\u0439  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.008390636149067664,0.009025144328396016,0.010438644233827938,0.015229349907657471,0.0189124068374136],"y":["\u0447\u0438\u0441\u043b\u0438\u0442\u0435\u043b\u044c\u043d\u043e\u0435  ","\u043f\u0440\u0438\u0437\u043d\u0430\u043a  ","\u0435\u0434\u0438\u043d\u0438\u0446\u0430  ","\u0441\u0435\u043c\u0430\u043d\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0439  ","\u0437\u043d\u0430\u0447\u0435\u043d\u0438\u0435  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.008545752265516895,0.008733815522703133,0.01142990741867705,0.015878549553943196,0.01740720418486918],"y":["\u043f\u0440\u0430\u0441\u043b\u0430\u0432\u044f\u043d\u0441\u043a\u0438\u0439  ","\u043b\u0438\u0442\u0435\u0440\u0430\u0442\u0443\u0440\u043d\u044b\u0439 \u044f\u0437\u044b\u043a  ","\u043b\u0438\u0442\u0435\u0440\u0430\u0442\u0443\u0440\u043d\u044b\u0439  ","\u0441\u043b\u0430\u0432\u044f\u043d\u0441\u043a\u0438\u0439  ","\u0438\u043d\u0434\u043e\u0435\u0432\u0440\u043e\u043f\u0435\u0439\u0441\u043a\u0438\u0439  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.008707372660475207,0.010169582311808369,0.010937026710438289,0.015642082429483416,0.019146002202801885],"y":["\u0440\u043e\u043c\u0430\u043d\u0441\u043a\u0438\u0439 \u044f\u0437\u044b\u043a  ","\u0444\u0440\u0430\u043d\u0446\u0443\u0437\u0441\u043a\u0438\u0439  ","\u0438\u0441\u043f\u0430\u043d\u0441\u043a\u0438\u0439  ","\u043f\u0438\u0441\u044c\u043c\u043e  ","\u0440\u043e\u043c\u0430\u043d\u0441\u043a\u0438\u0439  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.013928776152573962,0.013992512416665067,0.01584555350001714,0.0163563052142 ...

# %%
topic_model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="502ecee6-f5ea-4622-b8c2-1ec1a478717b" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("502ecee6-f5ea-4622-b8c2-1ec1a478717b")) {                    Plotly.newPlot(                        "502ecee6-f5ea-4622-b8c2-1ec1a478717b",                        [{"coloraxis":"coloraxis","name":"0","x":["0_\u0441\u043e\u0433\u043b\u0430\u0441\u043d\u044b\u0439_\u0444\u043e\u043d\u0435\u043c\u0430_\u0431\u044b\u0442\u044c","1_\u0431\u044b\u0442\u044c_\u0440\u0430\u0437\u0432\u0438\u0442\u0438\u0435_\u043c\u0435\u0442\u043e\u0434","2_\u0437\u043d\u0430\u0447\u0435\u043d\u0438\u0435_\u0440\u0435\u0447\u044c_\u0431\u044b\u0442\u044c","3_\u043b\u0438\u0442\u0435\u0440\u0430\u0442\u0443\u0440\u043d\u044b\u0439_\u0447\u0435\u043b_\u0432\u043e\u0441\u0442\u043e\u0447\u043d\u044b\u0439","4_\u0437\u043d\u0430\u0447\u0435\u043d\u0438\u0435_\u0441\u0435\u043c\u0430\u043d\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0439_\u0435\u0434...","5_\u0438\u043d\u0434\u043e\u0435\u0432\u0440\u043e\u043f\u0435\u0439\u0441\u043a\u0438\u0439_\u0441\u043b\u0430\u0432\u044f\u043d\u0441\u043a\u0438...","6_\u0440\u043e\u043c\u0430\u043d\u0441\u043a\u0438\u0439_\u043f\u0438\u0441\u044c\u043c\u043e_\u0438\u0441\u043f\u0430\u043d\u0441\u043a\u0438\u0439","7_\u0438\u043d\u0441\u0442\u0438\u0442\u0443\u0442_\u0441\u0441\u0441\u0440_\u043b\u0438\u0442\u043e\u0432\u0441\u043a\u0438\u0439","8_\u0430\u0440\u0430\u0431\u0441\u043a\u0438\u0439_\u043f\u0438\u0441\u044c\u043c\u043e_\u0437\u043d\u0430\u043a","9_\u0440\u0443\u0441\u0441\u043a\u0438\u0439_\u0440\u0443\u0441\u0441\u043a\u0438\u0439 \u044f\u0437\u044b\u043a_\u0441\u043b\u043e\u0432...","10_\u0447\u0435\u043b_\u043a\u043e\u043d\u0433\u043e\u043b\u0435\u0437\u0441\u043a\u0438\u0439_\u043d\u0438\u0433\u0435\u0440\u043e","11_\u043e\u0441\u0442\u0440\u043e\u0432_\u0447\u0435\u043b_\u043a\u0435\u0447\u0443\u0430","12_\u0431\u044b\u0442\u044c_\u0438\u0441\u0441\u043b\u0435\u0434\u043e\u0432\u0430\u043d\u0438\u0435_\u0438\u043d\u0434\u043e\u0435\u0432...","13_\u0440\u0430\u0437\u0432\u0438\u0442\u0438\u0435_\u043c\u0435\u0436\u0434\u0443\u043d\u0430\u0440\u043e\u0434\u043d\u044b\u0439_\u044f...","14_\u043f\u0438\u0441\u044c\u043c\u043e_\u0431\u0443\u043a\u0432\u0430_\u0430\u043b\u0444\u0430\u0432\u0438\u0442","15_\u043f\u043e\u0434\u0433\u0440\u0443\u043f\u043f\u0430_\u0441\u0443\u0434\u0430\u043d_\u0443\u0433\u0430\u043d\u0434\u0430","16_\u044e\u0436\u043d\u044b\u0439_\u043f\u0438\u0441\u044c\u043c\u043e_\u0430\u0446\u0442\u0435\u043a\u0441\u043a\u0438\u0439","17_\u0431\u0443\u043a\u0432\u0430_\u0440\u0443\u0441\u0441\u043a\u0438\u0439_\u0442\u0440\u0430\u043d\u0441\u043a\u0440\u0438\u043f\u0446\u0438\u044f","18_\u0440\u0435\u043a\u043e\u043d\u0441\u0442\u0440\u0443\u043a\u0446\u0438\u044f_\u043f\u0440\u0430\u044f\u0437\u044b\u043a_\u0442\u0435..."],"y":["0_\u0441\u043e\u0433\u043b\u0430\u0441\u043d\u044b\u0439_\u0444\u043e\u043d\u0435\u043c\u0430_\u0431\u044b\u0442\u044c","1_\u0431\u044b\u0442\u044c_\u0440\u0430\u0437\u0432\u0438\u0442\u0438\u0435_\u043c\u0435\u0442\u043e\u0434","2_\u0437\u043d\u0430\u0447\u0435\u043d\u0438\u0435_\u0440\u0435\u0447\u044c_\u0431\u044b\u0442\u044c","3_\u043b\u0438\u0442\u0435\u0440\u0430\u0442\u0443\u0440\u043d\u044b\u0439_\u0447\u0435\u043b_\u0432\u043e\u0441\u0442\u043e\u0447\u043d\u044b\u0439","4_\u0437\u043d\u0430\u0447\u0435\u043d\u0438\u0435_\u0441\u0435\u043c\u0430\u043d\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0439_\u0435\u0434...","5_\u0438\u043d\u0434\u043e\u0435\u0432\u0440\u043e\u043f\u0435\u0439\u0441\u043a\u0438\u0439_\u0441\u043b\u0430\u0432\u044f\u043d\u0441\u043a\u0438...","6_\u0440\u043e\u043c\u0430\u043d\u0441\u043a\u0438\u0439_\u043f\u0438\u0441\u044c\u043c\u043e_\u0438\u0441\u043f\ ...
